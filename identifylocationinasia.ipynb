# %%
# !pip install -q gradio
# Out:
#      |████████████████████████████████| 5.3 MB 8.7 MB/s
#      |████████████████████████████████| 212 kB 52.9 MB/s
#      |████████████████████████████████| 55 kB 2.9 MB/s
#      |████████████████████████████████| 270 kB 55.0 MB/s
#      |████████████████████████████████| 57 kB 4.5 MB/s
#      |████████████████████████████████| 112 kB 50.9 MB/s
#      |████████████████████████████████| 84 kB 3.0 MB/s
#      |████████████████████████████████| 84 kB 3.3 MB/s
#      |████████████████████████████████| 54 kB 3.0 MB/s
#      |████████████████████████████████| 2.3 MB 43.4 MB/s
#      |████████████████████████████████| 63 kB 2.0 MB/s
#      |████████████████████████████████| 80 kB 8.9 MB/s
#      |████████████████████████████████| 68 kB 5.2 MB/s
#      |████████████████████████████████| 46 kB 3.2 MB/s
#      |████████████████████████████████| 593 kB 31.2 MB/s
#      |████████████████████████████████| 4.0 MB 36.7 MB/s
#      |████████████████████████████████| 856 kB 46.6 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import gradio as gr
import matplotlib.pylab as plt
import PIL.Image as Image
import tensorflow as tf
import tensorflow_hub as hub

# %%
TF_MODEL_URL = 'https://tfhub.dev/google/on_device_vision/classifier/landmarks_classifier_asia_V1/1'
LABEL_MAP_URL = 'https://www.gstatic.com/aihub/tfhub/labelmaps/landmarks_classifier_asia_V1_label_map.csv'
IMAGE_SHAPE = (321, 321)

# %%
classifier = tf.keras.Sequential([hub.KerasLayer(TF_MODEL_URL,
                                                 input_shape=IMAGE_SHAPE+(3,),
                                                 output_key="predictions:logits")])

# %%
df = pd.read_csv(LABEL_MAP_URL)

# %%
label_map = dict(zip(df.id, df.name))

# %%
label_map
# Out:
# {0: 'Bagha Shahi Mosque',
#  1: 'City Palace',
#  2: 'The Immaculate Conception Cathedral of Cubao',
#  3: 'City of David',
#  4: 'Noor Mahal',
#  5: 'City of David',
#  6: 'Shree Muktinath Temple, Nepal',
#  7: 'Shivpuri Nagarjun National Park',
#  8: 'Nankin-machi',
#  9: 'Khao Sok National Park',
#  10: 'Mt. Goryu',
#  11: 'Milk Grotto Church',
#  12: 'Gili Trawangan',
#  13: 'Htukkant Thein Temple',
#  14: 'Yabakei Dam',
#  15: 'St. Francis of Assisi Parish Church',
#  16: 'Saint Hripsime Church',
#  17: 'Ranipuram',
#  18: "St. Joseph's Church, Beijing",
#  19: 'Tower of David',
#  20: 'Sandiaojiao Lighthouse',
#  21: 'Ngong Ping 360',
#  22: 'Chhatrapati Shivaji Terminus',
#  23: 'Sea of Galilee',
#  24: 'Khor Virab',
#  25: 'Shanti Stupa',
#  26: 'Sevanavank',
#  27: 'Izmenchivoye',
#  28: 'מצפה גדות',
#  29: 'Autumn-Admiring Pavilion',
#  30: 'Lohagad Fort',
#  31: "Humble Administrator's Garden",
#  32: 'Tiananmen Square',
#  33: 'Sree Thanumalayan Temple',
#  34: 'Menara Kuala Lumpur',
#  35: 'Lok Virsa Heritage Museum',
#  36: 'Batu Caves',
#  37: 'Khram Vo Imya Spasa Nerukotvornogo Obraza',
#  38: 'Lin Ma Hang',
#  39: 'Mount Arayat',
#  40: 'Daulatabad fort',
#  41: 'ارگ کریمخان',
#  42: 'Stalactite Cave Nature Reserve',
#  43: 'Wat Worachettharam',
#  44: 'Quezon City Hall',
#  45: 'Imam Reza Shrine',
#  46: 'Baliati Palace',
#  47: 'Minatogawa Park',
#  48: 'Takht-e Soleyman',
#  49: 'Vidyasagar Setu',
#  50: 'Lok Virsa Heritage Museum',
#  51: 'National Shrine and Parish of San Antonio de Padua',
#  52: 'Avraham Garden',
#  53: 'Gate of China, Nanjing',
#  54: 'Aichi Prefectural Library',
#  55: 'Rizal Memorial Baseball Stadium',
#  56: 'Mount Wutai',
#  57: 'Sai Ying Pun',
#  58: 'Omskiy Akademicheskiy Teatr Dramy',
#  59: 'JR HAKATA CITY',
#  60: 'Marikina Sports Center',
#  61: 'Cixiaojian Wanfang',
#  62: 'Shanhua Temple',
#  63: 'Nagarjuna Sagar Dam',
#  64: 'Cape Inamuragasaki',
#  65: 'Khram Arkhangela Mikhaila',
#  66: 'Resket Tower',
#  67: 'Tatevi Anapat',
#  68: 'The British Consulate at Takow',
#  69: 'Tomb of Ali Mardan Khan',
#  70: 'Bayon Temple',
#  71: 'হংসেশ্বরী মন্দির',
#  72: 'Abbey Falls Madkeri Falls',
#  73: 'National Shrine of Saint Anne',
#  74: 'Takaneshima Island',
#  75: 'Shah Mosque',
#  76: 'Kintrishi Nature Reserve',
#  77: 'The Beatitude Monastery',
#  78: "St George's Pilgrim Guest House",
#  79: 'Shalimar Bagh',
#  80: 'Futamiokitama Shrine',
#  81: "St. George's church",
#  82: 'Republic Monument',
#  83: 'Saif-ul-Mulook National Park',
#  84: 'Hadimba Devi Temple',
#  85: 'St. Jerome Parish Church',
#  86: 'Gaomei Wetlands',
#  87: 'Ganesha Ratha',
#  88: 'Uyskiy Sobor',
#  89: 'Đan Viện Châu Sơn',
#  90: 'Chien-Cheng Circle',
#  91: 'Porac Church',
#  92: 'Purana Qila',
#  93: 'Shinobazu Pond',
#  94: '臼杵城跡',
#  95: 'Singapore Flyer',
#  96: 'Qingjing Mosque',
#  97: 'Sanya Bay',
#  98: 'Tengboche Monastery',
#  99: 'Tomb of Akbar the Great',
#  100: 'St. James the Apostle',
#  101: 'Maiden Tower',
#  102: 'Warangal Fort',
#  103: 'Ciyunta',
#  104: 'Saint Hripsime Church',
#  105: 'Komazawa Olympic Park Athletic Stadium',
#  106: 'Temple of Heaven',
#  107: 'Guangxiao Temple',
#  108: 'The Golden Mount (Wat Saket)',
#  109: 'Katas Raj Temples',
#  110: 'Ikitsuki Bridge',
#  111: 'Dilijan Local Lore Museum & Picture Gallery',
#  112: 'Tianhou Museum',
#  113: 'Ahsan Manzil Museum',
#  114: 'Taichung Confucius Temple',
#  115: 'Aliyar Reservoir',
#  116: 'Holy Trinity Cathedral of Tbilisi',
#  117: 'Aghjots Vank Աղջոց վանք',
#  118: 'Mausoleum of Emperor Khai Dinh',
#  119: 'Sevanavank',
#  120: 'Beitou Hot Spring Museum',
#  121: 'Rohtas Fort',
#  122: 'Tel Qudadi',
#  123: 'Telangana State Archaeology Museum',
#  124: 'Noratus Cemetery',
#  125: 'Sayat-Nova monument',
#  126: 'Moder Gorob',
#  127: 'Borujerdiha Historical House',
#  128: 'Cavite Peninsula',
#  129: 'Fatih Mosque, Istanbul',
#  130: 'Bahla Fort',
#  131: 'Dhakeshwari Mandir',
#  132: 'Wat Ratcha Orasaram Ratchaworawihan (Chom Thong)',
#  133: 'Satya Dharma Temple',
#  134: 'Tatara Bridge',
#  135: 'Minsk Aircraft Carrier World',
#  136: 'Chocolate Hills',
#  137: 'Archdiocesan Shrine of Saint Anne',
#  138: 'Harichavank',
#  139: 'Wat Phra Yai',
#  140: 'Shinjuku i-LAND Tower',
#  141: 'Mahagandhayon Monastery',
#  142: 'Marco Polo Square',
#  143: 'Banghwa Bridge',
#  144: 'Ein Avdat National Park',
#  145: 'Khorshid Palace',
#  146: 'San Agustin Church',
#  147: 'Hunza Valley',
#  148: 'Al Khor Stadium',
#  149: "Temple of Bacchus (Roman's god of Wine)",
#  150: 'Veer Mata Jijabai Bhosale Udyan And Zoo',
#  151: 'Jallianwala Bagh',
#  152: 'Akal Takht',
#  153: 'Asian Civilisations Museum',
#  154: 'Bayon Temple',
#  155: 'San Miguel Arcangel Church',
#  156: 'Lower Kachura Lake',
#  157: 'Dawulun Fort',
#  158: 'Armenian Quarter',
#  159: 'Lodhi Garden',
#  160: 'Damascus Gate',
#  161: 'Balaoan Church',
#  162: 'Gorny Monastery',
#  163: 'Baiyun Temple',
#  164: 'Wat Maha That',
#  165: 'City of David',
#  166: 'Shalimar Bagh Mughal Garden',
#  167: 'Haeundae Beach',
#  168: 'Our Lady of Assumption Parish Church',
#  169: '⛱Ageeba Beach⛱',
#  170: 'Kazan',
#  171: 'Shushtar Historical Hydraulic System',
#  172: 'Purana Qila',
#  173: 'Chongwu City',
#  174: 'Baitul Aman Jame Masjid and Eidgah Complex',
#  175: 'Higashiyama Jisho-ji',
#  176: 'Seki-juku',
#  177: 'Shan Bridge',
#  178: 'Ozu Castle',
#  179: 'Vank Cathedral',
#  180: 'Momosuke Bridge',
#  181: 'Martand sun temple',
#  182: 'Cheonggyecheon',
#  183: 'Yanfu Temple',
#  184: 'Tipu Sultan Masjid Kolkata',
#  185: 'Kumrat Valley',
#  186: 'Dashtadem Fortress',
#  187: 'Hojuzan Risshaku Temple',
#  188: 'Munshi Ghat',
#  189: 'Shan Bridge',
#  190: 'Khosrov Forest State Reserve',
#  191: 'El Goli Building',
#  192: 'Chengqilou',
#  193: 'Atatürk pavilion',
#  194: 'Machhapuchhare',
#  195: 'Itmad-ud-Daula',
#  196: 'Rumelihisarı',
#  197: 'Mihrimah Sultan Mosque',
#  198: 'Wilayah Mosque',
#  199: 'Yuejiang Tower',
#  200: 'Mortuary Temple of Hatshepsut',
#  201: 'Shahi Eidgah',
#  202: 'Thousand Pillar Temple',
#  203: 'Soltanieh Dome',
#  204: 'Rohtas Fort',
#  205: 'Водонапорная башня',
#  206: 'Kazan',
#  207: 'Ha-Rishonim ba-Negev Site',
#  208: 'The Stone of Million',
#  209: 'Donggung Palace and Wolji Pond',
#  210: 'Potala Palace',
#  211: 'Holy Trinity Cathedral of Tbilisi',
#  212: 'Barasoain Church',
#  213: 'Basilica Minore del Santo Niño de Cebu',
#  214: 'Gubeikou',
#  215: 'Our Lady of Assumption Parish Church',
#  216: 'St. Bartholomew the Apostle Parish Church',
#  217: "Herod's Gate",
#  218: '中村家住宅 Nakamura Residence',
#  219: 'Shamakhi Astrophysical Observatory',
#  220: 'Tourism',
#  221: 'India Gate',
#  222: 'Tsiranavor',
#  223: '帝国生命保险台北支店',
#  224: 'Akashi Kaikyo National Government Park',
#  225: 'Vorotnaberd Fortress',
#  226: 'Damascus National Museum',
#  227: 'Givati Parking Lot dig',
#  228: 'Washigatozan',
#  229: 'Kwun Tong Promenade',
#  230: 'Jinpukaku',
#  231: 'Bateshwar Temple',
#  232: 'Dargah Hazrat Shaikh Ahmed Khattu Ganj Bakhs RA',
#  233: 'Diu Fort',
#  234: 'Hazarduari Palace',
#  235: 'Akashi-Kaikyo Bridge',
#  236: 'Kgbu "Gosudarstvennyy Muzey Istorii Literatury, Iskusstva I Kul\'tury Altaya"',
#  237: 'Hawa Mahal',
#  238: 'Maritime Museum',
#  239: 'Mandalay Hill',
#  240: 'Immaculate Conception Parish Church - Balayan',
#  241: 'Grand Mosque of Bursa',
#  242: 'Faisal Mosque',
#  243: 'Gol Gumbaz',
#  244: 'Qutub Minar Complex',
#  245: 'Shinjuku Golden Gai',
#  246: 'Shalimar Bagh',
#  247: 'Cupola of the Chain',
#  248: 'Sannomiya',
#  249: 'Golra Sharif Museum',
#  250: 'Ankara Castle',
#  251: 'Hauz Khas Complex',
#  252: 'Kangra Fort',
#  253: 'Noratus Cemetery',
#  254: 'Haji Ali Dargah',
#  255: 'San Luis Gonzaga Parish Church',
#  256: 'Nakatsu Castle',
#  257: 'All Saviors',
#  258: 'Qajar Museum',
#  259: 'Saint John the Baptist Parish Church',
#  260: 'Omar',
#  261: 'Yerevan Municipality',
#  262: 'Angkor Wat',
#  263: 'Damascus Gate',
#  264: 'CITIC Plaza',
#  265: 'Tel Aviv Port',
#  266: 'Noor Mahal',
#  267: 'Baoguo Temple',
#  268: 'Takanosu Central Park',
#  269: 'Wadi Ash Shab',
#  270: 'Masjid Bandaraya Kota Kinabalu',
#  271: "Xuguo's stone paifang",
#  272: 'Liaolei Residence',
#  273: 'Kuthodaw Pagoda',
#  274: 'Hayravank Monastery',
#  275: 'Monument of St. George',
#  276: 'Lok Virsa Heritage Museum',
#  277: 'Thian Hock Keng Temple',
#  278: 'Haifa Bay',
#  279: 'Nikortsminda',
#  280: 'Gndevank',
#  281: 'Wat Bowon Sathan Sutthawat',
#  282: 'Nahargarh Fort',
#  283: 'Tel Dan Nature Reserve',
#  284: 'Arako Kannon Temple',
#  285: 'Mt. Minenomatsume',
#  286: 'בית כנסת החורבה - Hurva Synagogue',
#  287: 'Jama Masjid',
#  288: 'Calcutta High Court',
#  289: 'Sanbō-in',
#  290: 'Huanglong',
#  291: 'Sisaket Temple',
#  292: 'Khosrov Forest State Reserve',
#  293: 'Shoghakat Church',
#  294: 'National Botanical Garden',
#  295: 'Anti-Taurus Mountains',
#  296: 'Putrajaya International Convention Centre',
#  297: 'Dowlat Abad Garden',
#  298: "Isa Khan's Tomb",
#  299: 'Tomb of Nader Shah',
#  300: 'Myokenhongu Chiba Shrine',
#  301: 'Saint Sargis Church',
#  302: 'Amaras Monastery',
#  303: 'Jal Mahal',
#  304: 'Kwun Tong',
#  305: 'Asahi River',
#  306: 'Nuestra Señora de Gracia Church',
#  307: 'Kukaldosh Madrasah',
#  308: 'Masjidh Al-Sulthan Muhammad Thakurufaanu Al-Auzam',
#  309: 'Shalimar Bagh',
#  310: 'Gate of China, Nanjing',
#  311: 'Mausoleum of Khoja Ahmed Yasawi',
#  312: "Workers' Party Foundation Monument",
#  313: 'Mount Kita',
#  314: 'Nanjing Bell Tower',
#  315: 'Dokai Bay',
#  316: "Nicholson's Obelisk",
#  317: 'St. James the Apostle',
#  318: 'The Pearl-Qatar',
#  319: "Krestovozdvizhenskaya Tserkov'",
#  320: 'Binondo Church',
#  321: 'St. Jerome Parish Church',
#  322: 'Wazir Khan Bath (Shahi Hammam)',
#  323: 'Sukjeongmun',
#  324: 'Lake Mashū',
#  325: 'Saint Gregory The Illuminator Cathedral',
#  326: 'Rakhu Bhagawati',
#  327: 'Musamman Burj',
#  328: 'Tezharuyk Monastery',
#  329: 'Wat Phrasi Rattana Mahathat',
#  330: 'Itsukushima Shrine',
#  331: "Dr. Sun Yat-sen's Mausoleum",
#  332: '建瓯东岳庙',
#  333: 'Daulatabad fort',
#  334: 'Saavira Kambada Basadi',
#  335: 'Matsumoto Castle',
#  336: 'Armenian Quarter',
#  337: 'Feroz Shah Kotla',
#  338: '奈多海岸',
#  339: 'Aimen',
#  340: 'Pingyao',
#  341: 'Masoudieh Palace',
#  342: 'Amoranto Sports Complex',
#  343: 'Bayon Temple',
#  344: 'Akhtala Monastery',
#  345: 'Sikandar Lodi Tomb',
#  346: 'The Santo Domingo Church and Convent',
#  347: 'Bayt Al-Suhaymi',
#  348: 'San Guillermo Parish Church',
#  349: 'Uyskiy Sobor',
#  350: 'Surb Hovhannes Church',
#  351: 'Ubud Palace',
#  352: 'National Museum of Singapore',
#  353: 'Saint Dominic Cathedral',
#  354: 'Aghazadeh Historical House',
#  355: 'Zvartnots Cathedral',
#  356: 'Al-Kauthar Mosque',
#  357: 'Tulsi shringar stores',
#  358: 'Tomb of Akbar the Great',
#  359: 'Jantar Mantar',
#  360: 'Takarazuka Grand Theater',
#  361: 'Independence Square',
#  362: 'Zhuzihu',
#  363: 'Aurangabad Caves',
#  364: 'Tomioka Hachimangu',
#  365: 'Bibliotheca Alexandrina',
#  366: 'Seki-juku',
#  367: 'Lake Pichola',
#  368: 'Taglang La',
#  369: 'St. John the Baptist Church',
#  370: 'Model of Jerusalem in 2nd Temple Period',
#  371: 'Taudaha Lake',
#  372: 'Naga Cathedral',
#  373: 'Sasuntsi Davit Statue',
#  374: 'Edith Wolfson Park',
#  375: 'Jiangnan Examination Hall',
#  376: 'The Adalaj Stepwell',
#  377: 'Yunfeng Temple (Pucheng)',
#  378: 'Mount Wutai',
#  379: 'Mount Nantai',
#  380: 'Fateh Sagar Lake',
#  381: 'Noratus Cemetery',
#  382: 'Jamia Masjid Srinagar',
#  383: 'Beppu Tower',
#  384: 'Mohenjo-daro',
#  385: 'Jantar Mantar - Jaipur',
#  386: 'Malampuzha Dam',
#  387: 'Wat Arun',
#  388: 'Saint Holy Mother of God Church',
#  389: 'Jog Falls',
#  390: 'Raja Haji Fisabilillah Mosque',
#  391: 'Daulatabad fort',
#  392: 'Makran',
#  393: 'Thma Bay Kaek',
#  394: 'Hayravank Monastery',
#  395: 'Herat Central Blue Mosque',
#  396: 'Yatsushirogu',
#  397: 'Docomo Tower',
#  398: 'Our Lady of Dolours Basilica',
#  399: 'Yasaka Shrine',
#  400: 'Metropolitan Building.',
#  401: 'Albert Hall Museum',
#  402: 'Kecharis Monastery',
#  403: 'Nangang Exhibition Center',
#  404: 'Hawa Mahal',
#  405: 'Nasir al-Mulk Mosque',
#  406: 'Nachi Falls',
#  407: 'Abdul Gafoor Mosque',
#  408: 'Saint Sargis Church',
#  409: 'Al Qusais 3',
#  410: 'Gassho-zukuri Minkaen',
#  411: 'Shree Muktinath Temple, Nepal',
#  412: 'Srisailam Reservoir',
#  413: 'Dashashwamedh Ghat',
#  414: 'Seonamsa',
#  415: 'Wat Benchamabophit',
#  416: 'Ryugyong Hotel',
#  417: 'Nanjing Road',
#  418: 'Brihadeeswara Temple',
#  419: 'Hualien Railway Culture Park',
#  420: 'Goshavank Monastery Complex',
#  421: 'Bahrain World Trade Center',
#  422: 'Old Town of Lijiang',
#  423: 'Yokohama Chinatown',
#  424: 'Dadiani Palace Museum',
#  425: 'Cheow Lan Lake',
#  426: 'Ratnagiri Monastery',
#  427: 'Sphinx of Memphis',
#  428: 'Hongshan Pagoda',
#  429: 'Saat Gombuj Jaame Masjid',
#  430: 'Dizengoff Square',
#  431: 'Hōzōmon Gate',
#  432: 'Poti St. Virgin Cathedral',
#  433: 'Rama VIII bridge',
#  434: 'Givat Olga',
#  435: 'Kabira bay',
#  436: 'Akhtala Monastery',
#  437: 'Our Lady of Assumption Parish Church',
#  438: 'Santo Cristo Parish Church',
#  439: 'Shanghai Museum',
#  440: 'Kinkaku-ji',
#  441: 'Hasedera',
#  442: 'Baitala Temple',
#  443: 'Kong Meng San Phor Kark See Monastery',
#  444: 'Cheng Hoon Teng Temple',
#  445: 'Amberd',
#  446: 'Holy Mother of God Church',
#  447: 'Lake Pichola',
#  448: 'Kailasanathar Temple',
#  449: 'Binondo Church',
#  450: 'Sisaket Temple',
#  451: 'Ōkuzure Coast',
#  452: 'Boat Quay',
#  453: 'Banpo Bridge',
#  454: 'Mera Peak',
#  455: 'Cheonmachong',
#  456: 'Wazir Khan Bath (Shahi Hammam)',
#  457: 'Kimiidera',
#  458: "Mosque of al-Salih Tala'i",
#  459: 'Tainan Municipal Tainan Cultural Center',
#  460: 'Otaru Canal',
#  461: 'Magic Bedouin Star',
#  462: 'Shinsekai',
#  463: 'Zoravor Surp Astvatsatsin Church',
#  464: 'Guangdong Museum of Revolutionary History',
#  465: 'Toki no Kane',
#  466: '伊江御殿墓',
#  467: 'SCN023 - Gnanambiga Sametha Sri Thenupureeswarar Thirukovil',
#  468: 'Safdarjung Tomb',
#  469: 'Philippine Arena',
#  470: 'Grand Mosque of West Sumatra',
#  471: 'Tashkent Tower',
#  472: 'Agrasen ki baoli',
#  473: 'Nacia Botanika Ĝardeno de Israelo',
#  474: 'National Museum of Tajikistan',
#  475: 'Temple of Confucius, Qufu',
#  476: 'Okayama Korakuen',
#  477: 'Pakistan Museum of Natural History',
#  478: "Sheikh Safi Al-Din Ardabili's Shrine",
#  479: 'Kaohsiung Confucius Temple',
#  480: 'Longquan Mountain',
#  481: 'Ozegahara',
#  482: 'Haghpat Monastery Complex',
#  483: 'Deyr Gachin Caravansary',
#  484: 'Baitul Mukarram National Mosque, Dhaka.',
#  485: 'Ancient Katzrin Park',
#  486: 'Wat Khung Taphao',
#  487: 'Donghai Island',
#  488: 'St. Ignatius Cathedral',
#  489: 'Shuanglin Temple',
#  490: 'Temple of Philae',
#  491: 'Buddha Dhatu Jadi',
#  492: 'India Gate',
#  493: 'Tomb of Nur Jahan',
#  494: 'Masumida Shrine',
#  495: 'Harichavank',
#  496: 'Agrasen ki baoli',
#  497: 'Pingyao',
#  498: 'Bolkar Mountains',
#  499: 'Wazir Khan Bath (Shahi Hammam)',
#  500: 'Eram Garden',
#  501: 'Municipal Corporation of Greater Mumbai',
#  502: 'Wakayama Prefectural Museum',
#  503: 'Seki-juku',
#  504: 'Hehuanshan',
#  505: 'San Luis Gonzaga Parish Church',
#  506: 'Naqsh-e Rostam',
#  507: 'The Adalaj Stepwell',
#  508: 'Kankalini Temple',
#  509: 'St. Francis CSI Church',
#  510: 'Government Museum, Mathura',
#  511: 'Nabi Mosque',
#  512: 'Chitwan National Park',
#  513: 'Dubai Marina',
#  514: 'Temple of King Ashoka',
#  515: 'Haicang Temple',
#  516: 'Black Dragon Pool',
#  517: 'Pawon Temple',
#  518: 'Sayat-Nova monument',
#  519: 'Red Fort',
#  520: 'Seokpajeong',
#  521: 'Qeysarie Gate',
#  522: 'The Beatitude Monastery',
#  523: 'Ananta Samakhom Throne Hall',
#  524: 'Dora Observatory',
#  525: 'Annapurna',
#  526: 'Haghpat Monastery Complex',
#  527: 'Jogyesa',
#  528: 'Kê Gà Lighthouse',
#  529: 'Triund',
#  530: 'Ancient Katzrin Park',
#  531: 'Ramat Sirin',
#  532: 'Noratus Cemetery',
#  533: 'Lukang Lungshan Temple',
#  534: 'Yiling Yangtze River Bridge',
#  535: 'Cattle Depot Artist Village',
#  536: 'Qutub Minar Complex',
#  537: 'Itmad-ud-Daula',
#  538: 'Anatolian Fortress',
#  539: '(Cavinti Church) Transfiguracion Parish Church',
#  540: 'Takashimaya Times Square',
#  541: 'Mother Armenia monument',
#  542: 'Nor Varagavank',
#  543: 'Parish of the Immaculate Heart of the Mother of God',
#  544: 'Kyoto Imperial Palace',
#  545: 'Manila Metropolitan Theater',
#  546: 'Old Town of Lijiang',
#  547: 'Seki-juku',
#  548: 'Kaptai Lake',
#  549: 'Almatti Dam',
#  550: 'בית ספר שדה שקמים',
#  551: 'Government Palace',
#  552: "Trajan's Kiosk",
#  553: 'Dudipatsar',
#  554: 'Temple No. 8 - Kumadani-ji',
#  555: 'Mount Mihara',
#  556: 'Armenian Opera Theatre',
#  557: 'The Minor Basilica and Metropolitan Cathedral of the Immaculate Conception',
#  558: 'Dhammayazaka(Dhammayazika) Pagoda',
#  559: 'Rabati Castle',
#  560: 'Shaolin Temple',
#  561: 'Stanley Military Cemetery',
#  562: 'Juche Tower',
#  563: 'Montefiore Windmill',
#  564: 'Wat Arun',
#  565: 'Taichung Prefectural Hall',
#  566: 'Plaza Lorenzo Ruiz',
#  567: 'El Goli Building',
#  568: 'Mahagandhayon Monastery',
#  569: 'Bada Gumbad',
#  570: 'Alaaddin Masjid Keykubad',
#  571: 'Angkor Wat',
#  572: 'Kowloon Peak',
#  573: 'Katskhi Column',
#  574: 'White Mosque',
#  575: 'Shanghai Museum',
#  576: 'Heavenly Lake of Tianshan',
#  577: 'Yavne-Yam',
#  578: 'Guandu Bridge',
#  579: 'All Saviors',
#  580: 'Fort De Kock',
#  581: 'Kunzum Pass',
#  582: 'Ako Castle Ruins',
#  583: 'Dhanmondi Eidgah Math',
#  584: 'Haghpat Monastery Complex',
#  585: 'Saint Gregory The Illuminator Cathedral',
#  586: 'Yudhishthir Chariot',
#  587: 'Sōji-ji',
#  588: 'Sardarapat Memorial',
#  589: 'Mount Arayat National Park',
#  590: 'Genbudo Park',
#  591: 'Mount Aragats',
#  592: 'Sevanavank',
#  593: 'Banjosa Lake',
#  594: 'Kobuleti Managed Reserve',
#  595: 'Mausoleum of Emperor Tu Duc',
#  596: 'Macao Museum',
#  597: 'Agamon Hula',
#  598: 'Pyramid of Djoser',
#  599: 'Safdarjung Tomb',
#  600: 'Puthia Rajbari',
#  601: 'Frere Hall',
#  602: 'Omar Ali Saifuddien Mosque, Brunei.',
#  603: 'Noratus Cemetery',
#  604: '銭形砂絵',
#  605: 'Tsunoshima Lighthouse',
#  606: 'Shevaroy Hills',
#  607: 'Amberd',
#  608: 'Mount Wutai',
#  609: 'Lad Khan Temple',
#  610: 'Qutub Minar Complex',
#  611: 'Kocatepe Mosque',
#  612: 'Armenian Church',
#  613: 'Cordillera Central',
#  614: 'Beit Hagefen',
#  615: 'Mortuary Temple of Hatshepsut',
#  616: 'Wangshan Tuku',
#  617: 'Minar-e-Pakistan',
#  618: 'Mithapukur Mosque',
#  619: 'Tseung Kwan O Sports Ground',
#  620: 'Chedi Luang Por Wat Monkhan',
#  621: 'Wat Thewarat Kunchon',
#  622: 'Mount Hiru',
#  623: "Jahangir's Tomb",
#  624: 'Wat Arun',
#  625: 'Jamaraat Bridge',
#  626: 'Mount of Olives',
#  627: "Sa'at Tower",
#  628: 'Saif-ul-Maluk Lake',
#  629: 'Jingshan Park',
#  630: 'Second Nanjing Yangtze Bridge',
#  631: 'Agamon Hula',
#  632: 'Holy Trinity Cathedral of Tbilisi',
#  633: 'Tajhat Palace',
#  634: 'Mohammad AlAmin Mosque',
#  635: 'Tatev Monastery',
#  636: 'Purana Qila',
#  637: "Ben-Gurion's Home",
#  638: 'Wulingyuan',
#  639: 'Dakshineswar Kali Temple',
#  640: 'Jahangir Mahal',
#  641: 'Tsitsernakaberd Armenian Genocide Memorial Complex',
#  642: 'Har Etan',
#  643: 'Gereja Kristen Protestan Indonesia',
#  644: 'Wat Arun',
#  645: 'Hunza Valley',
#  646: 'Goygol National Park',
#  647: 'Couch Potato',
#  648: 'Metekhi',
#  649: 'Kantajew Temple',
#  650: 'Tran Quoc Pagoda',
#  651: 'Liberty Square',
#  652: 'Kashueti St. George Church',
#  653: 'Echizenono Castle',
#  654: 'Montaza Palace',
#  655: 'Tomb of Akbar the Great',
#  656: 'Shalimar Bagh',
#  657: 'اناقة لندن',
#  658: 'Municipio de San Fernando',
#  659: 'Montaza Palace',
#  660: 'Ghalib Academy',
#  661: 'Harichavank',
#  662: 'Holy Trinity Cathedral of Tbilisi',
#  663: 'National Monument',
#  664: 'Fort St. Anthony of Simbor',
#  665: 'Raj Ghat',
#  666: 'Jodogahama Beach',
#  667: 'The National Gallery',
#  668: 'Dazhao Temple',
#  669: 'Tezharuyk Monastery',
#  670: 'Pingyao',
#  671: "Sekiguchi Catholic Church, St. Mary's Cathedral Tokyo",
#  672: 'Kecharis Monastery',
#  673: 'Kojirokuji Nabeshima Family Residence',
#  674: 'Naesosa',
#  675: '因島水軍城',
#  676: 'San Miguel Arcangel Church',
#  677: 'Mount Makiling',
#  678: 'Begumpur Mosque',
#  679: 'Maiden Tower',
#  680: 'Western Wall',
#  681: 'Singapore Flyer',
#  682: 'National Library of Korea',
#  683: 'Hatirjheel',
#  684: 'Lion Rock',
#  685: 'Former Residence of Cai Yuanpei',
#  686: 'Guanyin of Nanshan',
#  687: 'Eram Garden',
#  688: 'Feroz Shah Kotla',
#  689: 'Muslim Quarter',
#  690: 'prime electronic service center',
#  691: 'Gökova Körfezi',
#  692: 'Wat Phra Chetuphon (Wat Pho - reclining Buddha)',
#  693: 'Temple Of Khonsu',
#  694: 'Moon Lake',
#  695: 'Saif-ul-Maluk Lake',
#  696: 'Zvartnots Cathedral',
#  697: 'JR Central Towers',
#  698: 'Star Ferry Pier, Tsim Sha Tsui',
#  699: 'Sukhna Lake',
#  700: 'Neghuts Vank',
#  701: 'Apadana Palace',
#  702: 'Mohammed Amin Khan Madrassah',
#  703: 'Guangxiao Temple',
#  704: 'Taipei Guest House',
#  705: 'Itmad-ud-Daula',
#  706: 'Athirappilly Water Falls',
#  707: 'The Immaculate Conception Cathedral of Cubao',
#  708: 'Mahagandhayon Monastery',
#  709: "De'anli",
#  710: 'Peace Sculpture',
#  711: 'Douliu Baseball Field',
#  712: 'Purana Qila',
#  713: 'St John In The Wilderness Monastery',
#  714: 'Mount of Olives',
#  715: 'Kongobuji',
#  716: 'Kintai Bridge',
#  717: 'Yungang Grottoes',
#  718: 'Phimeanakas',
#  719: 'Puthia Rajbari',
#  720: 'Svetitskhoveli Cathedral',
#  721: 'Noratus Cemetery',
#  722: 'Azadi Tower',
#  723: 'Jinoshima Island',
#  724: 'St. James the Apostle',
#  725: 'India Gate',
#  726: "St. Peter's Church",
#  727: 'Our Lady of Assumption Parish Church',
#  728: 'Mount Wutai',
#  729: 'Arita Porcelain Park',
#  730: 'Xuanwu Lake',
#  731: 'Hotel Lisboa',
#  732: 'Kami-shima',
#  733: 'Hong Kong Cultural Centre',
#  734: 'Tel Akko',
#  735: 'Rumelihisarı',
#  736: 'Amir Timur Museum',
#  737: 'Monastery of Saint Stepanos',
#  738: 'Juche Tower',
#  739: 'David Sassoon Library and Reading Room',
#  740: 'Chizenin',
#  741: 'Champaner-Pavagadh Archaeological Park',
#  742: 'Shiraito Falls',
#  743: 'Mazar E Quaid, Jinnah Mausoleum',
#  744: 'San Sebastian Parish Church',
#  745: 'Temple of Yan Hui',
#  746: 'Chords Bridge',
#  747: 'Shanhua Temple',
#  748: 'Ha-Rishonim ba-Negev Site',
#  749: 'Puthia Rajbari',
#  750: 'Temple of Khnum',
#  751: 'Karmravor Church',
#  752: 'Museum of the Good Samaritan - The Good Samaritan Museum',
#  753: 'The Santo Domingo Church and Convent',
#  754: 'Butsushozan Raigoin Honen Temple',
#  755: '恭城文庙',
#  756: 'Hunza Valley',
#  757: 'Pyramid of Khafre',
#  758: 'Prang Sam Yod',
#  759: 'Ratti Gali Lake',
#  760: 'Chubi Bridge',
#  761: 'Secunderabad Junction railway station',
#  762: 'Yungang Grottoes',
#  763: 'Mount Arayat',
#  764: 'Kidal Temple ꦕꦤ꧀ꦢꦶꦏꦶꦢꦭ꧀',
#  765: 'Kim Il-sung Stadium',
#  766: 'The Dubai Fountain',
#  767: 'Kingdom Tower',
#  768: 'Gulmarg Gondola',
#  769: 'Ozero Turgoyak',
#  770: 'Mayon Volcano',
#  771: 'Oeghtasar',
#  772: 'Yuecheng Longmu Zumiao',
#  773: 'Caesarea National Park',
#  774: 'Santuario de San Jose Parish',
#  775: 'Basilica of the Annunciation',
#  776: 'Hunza Valley',
#  777: 'Nanchan Temple',
#  778: 'Cixiaojian Wanfang',
#  779: 'Purana Qila',
#  780: 'Wat Kasattrathirat Worawihan',
#  781: 'Old Town of Lijiang',
#  782: 'Rizal Memorial Coliseum',
#  783: 'Batu Sapi',
#  784: 'Bhimbetka rock shelters',
#  785: 'Saghmosavank',
#  786: 'Mingun Pahtodawgyi',
#  787: '85 Sky-tower CTtraveller Suit',
#  788: 'Pakistan Monument',
#  789: 'Government Museum, Mathura',
#  790: 'Baclayon Church',
#  791: 'Kwun Tong',
#  792: 'Jagdish Temple',
#  793: 'Barasoain Church',
#  794: 'Muzey-Zapovednik Sunduki',
#  795: 'Hualin Temple',
#  796: 'Namdapha National Park',
#  797: 'Bardzrakach',
#  798: 'Temple of Kom Ombo',
#  799: 'Presidential Office Building',
#  800: 'Saint Sargis Monastery',
#  801: 'En Afek',
#  802: 'Karuizawa Shiraito Falls',
#  803: 'Mor Gabriel Monastery',
#  804: 'National Martyrs Cemetery',
#  805: 'The Cathedral of St. Simeon Stylite',
#  806: 'Suwon Hwaseong Fortress',
#  807: 'San Miguel Arcangel Church',
#  808: 'Itsukushima Shrine',
#  809: 'Lok Virsa Heritage Museum',
#  810: 'Gwangan Bridge',
#  811: 'St. Mary Magdalene Parish Church',
#  812: 'Zhuzihu',
#  813: 'Anbariya Mosque',
#  814: 'Jokhang Temple',
#  815: 'Tsitsernakaberd Armenian Genocide Memorial Complex',
#  816: 'Salar Jung Museum',
#  817: 'Azrieli Center',
#  818: 'Ynares Center',
#  819: 'Tin Shui Wai Park',
#  820: 'Church of the Visitation',
#  821: 'Golra Sharif Museum',
#  822: 'Hanging Temple',
#  823: 'Shaheed A. H. M. Qamaruzzaman Stadium',
#  824: 'San Nicolas de Tolentino Church',
#  825: 'Vodafone Park',
#  826: 'Arch of Reunification',
#  827: 'Ashkelon National Park',
#  828: 'Kamo River',
#  829: 'Zoharei Chama Synagogue',
#  830: 'Trucks and transport museum',
#  831: 'Wadi Degla Protectorate',
#  832: 'Frere Hall',
#  833: 'Chittor Fort',
#  834: 'Iwashi Island',
#  835: 'Langkawi Skybridge cable car',
#  836: 'Or Torah Synagogue',
#  837: 'Tel Akko',
#  838: 'Former Residence of Cai Yuanpei',
#  839: 'Lake Kussharo',
#  840: 'Bangabandhu Sheikh Mujibur Rahman Novo Theatre',
#  841: 'Puthia Rajbari',
#  842: 'Singapore Philatelic Museum',
#  843: 'Taurus Mountains',
#  844: 'Church Saint Jacob',
#  845: 'Sajikot Waterfalls',
#  846: 'Elephant Orphanage (Zoo)',
#  847: 'Kecharis Monastery',
#  848: 'Mithapukur Mosque',
#  849: '栗毓美墓',
#  850: 'Sarat Chandra Chattopadhyay Kuthi',
#  851: 'Harichavank',
#  852: 'U Bein Bridge',
#  853: 'Nageshvara Jyotirling',
#  854: 'Palace of The Shirvanshahs',
#  855: 'Wat Rakhang Khositaram',
#  856: 'Gate of All Nations\u200c',
#  857: 'Phayathai Palace',
#  858: 'West Lake',
#  859: 'Roda Temples',
#  860: 'Downtown Dubai',
#  861: 'ChoghaZanbil Ziggurat',
#  862: 'Pantomima Teatrı',
#  863: 'HaMakhtesh HaGadol',
#  864: 'Perga',
#  865: 'Kanchanaburi War Cemetery',
#  866: 'Baylar Mosque',
#  867: 'Malolos Cathedral',
#  868: 'Kikko Park',
#  869: 'The Clock Tower',
#  870: 'Long Biên Bridge',
#  871: 'Honnoji',
#  872: 'Mt. Gongen',
#  873: 'Sai Ying Pun',
#  874: 'Cathedral of Saint Paul the First Hermit',
#  875: 'Herodion National Park',
#  876: 'Bhairav Nath Mandir',
#  877: "Bell Tower of Xi'an",
#  878: 'Guandu Bridge',
#  879: 'Gimje Dongheon',
#  880: 'Galle Face Green',
#  881: 'Hazrat Hazi Khawja Shahbaz Khan Mosque',
#  882: 'Emirgan Park',
#  883: 'Khor Virab',
#  884: 'St. Mark Coptic Orthodox Church Cleopatra',
#  885: 'Qutub Minar Complex',
#  886: 'Junagarh Fort, Bikaner',
#  887: 'Mifuneyama Rakuen',
#  888: 'Descent of the Ganges',
#  889: 'West Lake',
#  890: 'National Chiang Kai-shek Memorial Hall',
#  891: 'Bibliotheca Alexandrina',
#  892: 'Rang Ghar',
#  893: 'Sigiriya Fortress',
#  894: 'Aghjots Vank Աղջոց վանք',
#  895: 'Stalactite Cave Nature Reserve',
#  896: 'Varkala Beach',
#  897: 'Immaculate Conception Parish Church',
#  898: 'Shah Jahan Mosque',
#  899: 'Bhoga Nandishwara Temple',
#  900: 'Shoshazan Engyo-ji temple',
#  901: 'Lmbatavank',
#  902: 'Narikala Fortress',
#  903: 'Aga Khan Mausoleum',
#  904: 'Navotas Centennial Park',
#  905: 'Jerash park',
#  906: 'Shwedagon Pagoda',
#  907: 'Wuxi County Library Former Site',
#  908: 'Zinat Al-Molk House',
#  909: 'Unfinished Obelisk',
#  910: 'Talin Cathedral Monastery Complex',
#  911: 'Harichavank',
#  912: 'Tiantong Temple',
#  913: 'Kanagawa Prefectural Museum of Cultural History',
#  914: 'Alexander III',
#  915: 'Dowlat Abad Garden',
#  916: 'Nagore Dargah',
#  917: 'Matsuo-Taisha Shrine',
#  918: 'Handover Gifts Museum of Macao',
#  919: 'Marco Polo Square',
#  920: "Ci'en Pagoda",
#  921: 'James prinsep',
#  922: 'Ratnagiri Monastery',
#  923: 'Minor Basilica of the Immaculate Conception',
#  924: 'Shahzadeh Mahan Historical Garden',
#  925: 'Lodhi Garden',
#  926: 'Edith Wolfson Park',
#  927: 'Saint Hripsime Church',
#  928: 'Akoshi Public Library',
#  929: 'Montefiore Windmill',
#  930: 'Hunza Valley',
#  931: '恭城文庙',
#  932: 'Maijishan Grottoes',
#  933: 'Pakistan Monument',
#  934: "A Bing's Former Residence",
#  935: 'Aoyama Cemetery',
#  936: 'Martand sun temple',
#  937: 'Ishak Pasha Palace',
#  938: 'Heian Shrine',
#  939: 'Kuwait Towers',
#  940: 'Nor Varagavank',
#  941: 'Qingtiangang Grassland',
#  942: 'Star Ferry Pier, Tsim Sha Tsui',
#  943: 'Holy Mother of God Kathoghike Church',
#  944: 'Banjosa Lake',
#  945: 'Golestan Palace',
#  946: 'Metekhi St. Virgin Church',
#  947: 'Shamlaji Temple',
#  948: 'JR HAKATA CITY',
#  949: 'Alexandria Opera House',
#  950: 'Dakshineswar Kali Temple',
#  951: "St. Martin's Island",
#  952: 'Nizami Museum of Azerbaijan Literature',
#  953: 'Akhayat sinkhole',
#  954: 'Basilica of the Annunciation',
#  955: 'U Bein Bridge',
#  956: 'Izumigaoka Country Club',
#  957: 'Leh Palace',
#  958: 'Rajah Sulayman Park',
#  959: 'The Temple of Horus at Edfu',
#  960: "Sheikh Safi Al-Din Ardabili's Shrine",
#  961: 'Abou al-Haggag Mosque',
#  962: 'Bedi mahal',
#  963: 'Changhua Roundhouse',
#  964: 'Saral Lake',
#  965: 'Kawayu onsen',
#  966: 'Company Of Jesus Square',
#  967: 'Clark Veterans Cemetery',
#  968: 'Immaculate Conception Parish Church',
#  969: 'Mochou Lake',
#  970: 'Kaminarimon Gate Senso-ji',
#  971: 'Rodina',
#  972: 'Ngong Ping 360',
#  973: 'Jinji Lake',
#  974: 'Aghavnavank Monastery',
#  975: 'Loboc River',
#  976: 'Nikortsminda',
#  977: 'Taipei Zoo',
#  978: 'Wat Maha That',
#  979: 'Varaha Cave',
#  980: 'წუღრუღაშენი',
#  981: 'Bara Imambara',
#  982: 'Kushumba Mosque, Naogoan',
#  983: 'Mount Ibuki',
#  984: 'Immaculate Conception Parish Church',
#  985: 'Nakanoshima',
#  986: 'Victoria Memorial',
#  987: 'Church Saint Jacob',
#  988: 'Liberty Square',
#  989: 'Al-Estiqlal',
#  990: 'Suwon Hwaseong Fortress',
#  991: 'Tiantong Temple',
#  992: 'Government Museum',
#  993: 'Nalanda Gedige',
#  994: 'Hanuman Dhoka Durbar Museum ( येँ लयाकु )',
#  995: 'White Tower',
#  996: "Hisham's Palace",
#  997: 'Quezon City Hall',
#  998: 'Caesarea National Park',
#  999: 'Mallikarjuna Temple',
#  ...}

# %%
img_loc = "img.jpg"

# %%
img = Image.open(img_loc).resize(IMAGE_SHAPE)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=321x321 at 0x7F2BFA349E90>

# %%
img = np.array(img)/255.0
img.shape
# Out:
# (321, 321, 3)

# %%
img = img[np.newaxis, ...]

# %%
img.shape
# Out:
# (1, 321, 321, 3)

# %%
result = classifier.predict(img)
result
# Out:
# 1/1 [==============================] - 4s 4s/step
# array([[ 0.22107123,  0.21158077,  0.05807929, ...,  0.17497349,
#          0.14780754, -0.00152766]], dtype=float32)

# %%
result.shape
# Out:
# (1, 98960)

# %%
label_map[np.argmax(result)]
# Out:
# 'Itmad-ud-Daula'

# %%
class_names=list(label_map.values())

# %%
def classify_image(image):
    img = np.array(image)/255.0
    img = img[np.newaxis, ...]
    prediction = classifier.predict(img)
    return label_map[np.argmax(prediction)]

# %%
image = gr.inputs.Image(shape=(321, 321))
label = gr.outputs.Label(num_top_classes=1)

gr.Interface(
    classify_image, 
    image, 
    label,
    capture_session=True).launch(debug=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `capture_session` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://3a794c1b2bfc30ad.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://3a794c1b2bfc30ad.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 [==============================] - 0s 93ms/step
